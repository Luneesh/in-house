# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
import scanpy as sc
import torch
import scarches as sca
import numpy as np
import gdown
# Out:
# WARNING:root:In order to use the mouse gastrulation seqFISH datsets, please install squidpy (see https://github.com/scverse/squidpy).
# WARNING:root:In order to use sagenet models, please install pytorch geometric (see https://pytorch-geometric.readthedocs.io) and
#  captum (see https://github.com/pytorch/captum).
# WARNING:root:mvTCR is not installed. To use mvTCR models, please install it first using "pip install mvtcr"
# WARNING:root:multigrate is not installed. To use multigrate models, please install it first using "pip install multigrate".

# %%
sc.set_figure_params(frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %%
adata = sc.read('tyser.h5ad')
#hips = sc.read("hiPSC.h5ad")

# %%
adata.T
# Out:
# AnnData object with n_obs × n_vars = 57490 × 1069
#     obs: 'features'
#     var: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt'

# %%
print(adata.X.shape)
print(adata.X[:5, :5])  # View a small slice
# Out:
# (1069, 57490)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3 stored elements and shape (5, 5)>
#   Coords	Values
#   (0, 0)	2.0
#   (2, 0)	2.0
#   (4, 1)	1.0

# %%
#adata.X = adata.layers["counts"].copy()
# Use adata.X directly, as it contains raw counts.
adata.X = adata.X.copy()

# %%
sca.utils.add_annotations(adata, 'reactome.gmt', min_genes=12, clean=True)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
sc.pp.normalize_total(adata)

# %%
sc.pp.log1p(adata)

# %%
print(adata.obs.keys())
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name',
#        'Characteristics.sampling.site.',
#        'Characteristics.inferred.cell.type...authors.labels.',
#        'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id',
#        'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint',
#        'percent.mt'],
#       dtype='object')

# %%
#adata.obs['batch'] = 'reference'

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    batch_key="batch",
    subset=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sc.pp.highly_variable_genes(
#       2     adata,
#       3     n_top_genes=2000,
#       4     batch_key="orig.ident",  # Pass the column name as a string
#       5     subset=True
#       6 )
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\legacy_api_wrap\__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:684, in highly_variable_genes(***failed resolving arguments***)
#     680     df = _highly_variable_genes_single_batch(
#     681         adata, layer=layer, cutoff=cutoff, n_bins=n_bins, flavor=flavor
#     682     )
#     683 else:
# --> 684     df = _highly_variable_genes_batched(
#     685         adata, batch_key, layer=layer, cutoff=cutoff, n_bins=n_bins, flavor=flavor
#     686     )
#     688 logg.info("    finished", time=start)
#     690 if not inplace:
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:431, in _highly_variable_genes_batched(adata, batch_key, layer, n_bins, flavor, cutoff)
#     421 def _highly_variable_genes_batched(
#     422     adata: AnnData,
#     423     batch_key: str,
#    (...)
#     428     cutoff: _Cutoffs | int,
#     429 ) -> pd.DataFrame:
#     430     sanitize_anndata(adata)
# --> 431     batches = adata.obs[batch_key].cat.categories
#     432     dfs = []
#     433     gene_list = adata.var_names
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\pandas\core\arrays\categorical.py:2849, in CategoricalAccessor.__init__(self, data)
#    2848 def __init__(self, data) -> None:
# -> 2849     self._validate(data)
#    2850     self._parent = data.values
#    2851     self._index = data.index
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\pandas\core\arrays\categorical.py:2858, in CategoricalAccessor._validate(data)
#    2855 @staticmethod
#    2856 def _validate(data):
#    2857     if not is_categorical_dtype(data.dtype):
# -> 2858         raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
select_terms = adata.varm['I'].sum(0) > 12
adata.uns['terms'] = np.array(adata.uns['terms'])[select_terms].tolist()
adata.varm['I'] = adata.varm['I'][:, select_terms]

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1) > 0)

# %%
adata.X = adata.X.copy()

# %%
intr_cvae = sca.models.EXPIMAP(
    adata=adata,
    condition_key='batch',
    hidden_layer_sizes=[256, 256, 256],
    recon_loss='nb'
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1977 256 1
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 224
# Decoder Architecture:
# 	Masked linear layer in, ext_m, ext, cond, out:  224 0 0 1 1977
# 	with hard mask.
# Last Decoder layer: softmax

# %%
ALPHA = 0.7

# %%
adata.X = adata.X.astype(np.float32)

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss", # val_unweighted_loss
    "threshold": 0,
    "patience": 50,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}
intr_cvae.train(
    n_epochs=400,
    alpha_epoch_anneal=100,
    alpha=ALPHA,
    alpha_kl=0.5,
    weight_decay=0.,
    early_stopping_kwargs=early_stopping_kwargs,
    use_early_stopping=True,
    monitor_only_val=False,
    seed=2020,
)
# Out:
# Preparing (1069, 1977)
# Instantiating dataset
# Init the group lasso proximal operator for the main terms.
#  |████████████████████| 100.0%  - epoch_loss: 1328.3395996094 - epoch_recon_loss: 1293.7477264404 - epoch_kl_loss: 69.1837148666 - val_loss: 1340.6939697266 - val_recon_loss: 1306.8558349609 - val_kl_loss: 67.676307678236
# Saving best state of network...
# Best State was in Epoch 397

# %%
MEAN = False

# %%
adata.obsm['X_cvae'] = intr_cvae.get_latent(mean=MEAN, only_active=True)

# %%
sc.pp.neighbors(adata, use_rep='X_cvae')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['Characteristics.inferred.cell.type...authors.labels.'], frameon=False)

# %%
# Lees de query-dataset
hips = sc.read('hiPSC.h5ad')

# Controleer de overlap van genen
#missing_genes = [gene for gene in adata.var_names if gene not in hips.var_names]
#print(f"Aantal genen in hips die niet in tyser staan: {len(missing_genes)}")
#print("Ontbrekende genen:", missing_genes)

# %%
# Filter genen die aanwezig zijn in beide datasets
#common_genes = [gene for gene in adata.var_names if gene in hips.var_names]

# Pas de filtering toe op beide datasets
#hips = hips[:, common_genes].copy()
#adata = adata[:, common_genes].copy()

# %%
hips = sc.read('hiPSC.h5ad')[:, hips.var_names].copy()

# %%
# Controleer of var_names overeenkomen
#print("Aantal genen in beide datasets na filtering:", len(common_genes))
#print("Zijn genen nu identiek?", np.array_equal(hips.var_names, hips.var_names))

# %%
hips.obs['batch'] = 'reference'

# %%
hips.obs
# Out:
#                                            orig.ident  nCount_RNA  \
# batch_2_A_AAACCCAAGGTAATCA-1            SeuratProject     48806.0
# batch_2_A_AAAGGATCATCCAATG-1            SeuratProject      5460.0
# batch_2_A_AAAGGATGTGGTCAAG-1            SeuratProject     32899.0
# batch_2_A_AAAGGTAGTGTCATCA-1            SeuratProject     37327.0
# batch_2_A_AAATGGACATATCTGG-1            SeuratProject     18633.0
# ...                                               ...         ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1  SeuratProject     14013.0
# batch_1_sample_120H_TTTCACATCAGCCCAG-1  SeuratProject     21173.0
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1  SeuratProject     22107.0
# batch_1_sample_120H_TTTGATCAGCTCCATA-1  SeuratProject     12806.0
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1  SeuratProject     32140.0
#
#                                         nFeature_RNA   run sample_name  \
# batch_2_A_AAACCCAAGGTAATCA-1                    6892  0h_A   iPSC_99_4
# batch_2_A_AAAGGATCATCCAATG-1                    2307  0h_A   iPSC_99_4
# batch_2_A_AAAGGATGTGGTCAAG-1                    5707  0h_A   iPSC_99_4
# batch_2_A_AAAGGTAGTGTCATCA-1                    6069  0h_A   iPSC_99_4
# batch_2_A_AAATGGACATATCTGG-1                    4701  0h_A   iPSC_99_4
# ...                                              ...   ...         ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1          4629  120h   iPSC_72_1
# batch_1_sample_120H_TTTCACATCAGCCCAG-1          5140  120h   iPSC_72_1
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1          5437  120h   iPSC_72_1
# batch_1_sample_120H_TTTGATCAGCTCCATA-1          4127  120h   iPSC_72_1
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1          5614  120h   iPSC_72_1
#
#                                         percent.mt  percent.dissoc  \
# batch_2_A_AAACCCAAGGTAATCA-1              5.110027        0.013308
# batch_2_A_AAAGGATCATCCAATG-1              0.201465        0.015073
# batch_2_A_AAAGGATGTGGTCAAG-1              4.097389        0.014101
# batch_2_A_AAAGGTAGTGTCATCA-1              4.532912        0.013420
# batch_2_A_AAATGGACATATCTGG-1              4.932110        0.013176
# ...                                            ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1    4.767002        0.017398
# batch_1_sample_120H_TTTCACATCAGCCCAG-1    4.127899        0.014142
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1    2.035554        0.013721
# batch_1_sample_120H_TTTGATCAGCTCCATA-1    3.428081        0.015297
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1    2.722464        0.013653
#
#                                        RNA_snn_res.0.3 seurat_clusters  \
# batch_2_A_AAACCCAAGGTAATCA-1                         2               0
# batch_2_A_AAAGGATCATCCAATG-1                         7               0
# batch_2_A_AAAGGATGTGGTCAAG-1                         2               0
# batch_2_A_AAAGGTAGTGTCATCA-1                         2               0
# batch_2_A_AAATGGACATATCTGG-1                         2               0
# ...                                                ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1               3               2
# batch_1_sample_120H_TTTCACATCAGCCCAG-1               5               4
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1               3               2
# batch_1_sample_120H_TTTGATCAGCTCCATA-1               3               2
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1               3               2
#
#                                         RNA_snn_res.0.22      batch
# batch_2_A_AAACCCAAGGTAATCA-1                           0  reference
# batch_2_A_AAAGGATCATCCAATG-1                           0  reference
# batch_2_A_AAAGGATGTGGTCAAG-1                           0  reference
# batch_2_A_AAAGGTAGTGTCATCA-1                           0  reference
# batch_2_A_AAATGGACATATCTGG-1                           0  reference
# ...                                                  ...        ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1                 2  reference
# batch_1_sample_120H_TTTCACATCAGCCCAG-1                 4  reference
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1                 2  reference
# batch_1_sample_120H_TTTGATCAGCTCCATA-1                 2  reference
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1                 2  reference
#
# [4694 rows x 11 columns]

# %%
#hips.uns['terms'] = adata.uns['terms']

# %%
q_intr_cvae = sca.models.EXPIMAP.load_query_data(hips, intr_cvae)
# Out:
# WARNING:scarches.models.base._utils:WARNING: Query shares 7.8197% of its genes with the reference.This may lead to inaccuracy in the results.
# Query data is missing expression data of  136  genes which were contained in the reference dataset.
# The missing information will be filled with zeroes.
# Query data contains expression data of  21702  genes that were not contained in the reference dataset. This information will be removed from the query data object for further processing.
# AnnData object with n_obs × n_vars = 4694 × 1977
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'run', 'sample_name', 'percent.mt', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22', 'batch'
#
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1977 256 1
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 224
# Decoder Architecture:
# 	Masked linear layer in, ext_m, ext, cond, out:  224 0 0 1 1977
# 	with hard mask.
# Last Decoder layer: softmax

# %%
q_intr_cvae.train(n_epochs=400, alpha_epoch_anneal=100, weight_decay=0., alpha_kl=0.1, seed=2020, use_early_stopping=True)
# Out:
# Preparing (4694, 1977)
# Instantiating dataset
#  |█████---------------| 27.8%  - val_loss: 1124.2645874023 - val_recon_loss: 1119.0965576172 - val_kl_loss: 51.6803827286
# ADJUSTED LR
#  |█████---------------| 29.5%  - val_loss: 1124.5440673828 - val_recon_loss: 1119.3769226074 - val_kl_loss: 51.6716289520
# Stopping early: no improvement of more than 0 nats in 20 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 96

# %%
dataset_samen = sc.AnnData.concatenate(adata, hips, batch_key='batch_join', uns_merge='same')

# %%
dataset_samen
# Out:
# AnnData object with n_obs × n_vars = 5763 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt', 'batch', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22', 'batch_join'
#     var: 'features', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'highly_variable_nbatches-0', 'highly_variable_intersection-0'
#     obsm: 'X_umap'

# %%
dataset_samen.X = dataset_samen.X.astype(np.float32)
#adata.X = adata.X.astype(np.float32)

# %%
dataset_samen.obs.batch
# Out:
# SS.sc7786612-0                              reference
# SS.sc7786605-0                              reference
# SS.sc7785737-0                              reference
# SS.sc7785398-0                              reference
# SS.sc7788091-0                              reference
#                                               ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1    reference
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1    reference
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1    reference
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1    reference
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1    reference
# Name: batch, Length: 5763, dtype: object

# %%
# Out:
# Obs shape: (5763, 20)
# Var shape: (1841, 7)
# X shape: (5763, 1841)

# %%
dataset_samen.obs
# Out:
#                                              orig.ident     nCount_RNA  \
# SS.sc7786612-0                                        0  259888.990001
# SS.sc7786605-0                                        0  437911.014986
# SS.sc7785737-0                                        0  322351.983054
# SS.sc7785398-0                                        0  394318.996000
# SS.sc7788091-0                                        0  298217.993000
# ...                                                 ...            ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1  SeuratProject   14013.000000
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1  SeuratProject   21173.000000
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1  SeuratProject   22107.000000
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1  SeuratProject   12806.000000
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1  SeuratProject   32140.000000
#
#                                           nFeature_RNA   Source.Name  \
# SS.sc7786612-0                                    6942  SS.sc7786612
# SS.sc7786605-0                                    6140  SS.sc7786605
# SS.sc7785737-0                                    3800  SS.sc7785737
# SS.sc7785398-0                                    2964  SS.sc7785398
# SS.sc7788091-0                                    5030  SS.sc7788091
# ...                                                ...           ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1          4629           NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1          5140           NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1          5437           NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1          4127           NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1          5614           NaN
#
#                                          Characteristics.sampling.site.  \
# SS.sc7786612-0                                                  rostral
# SS.sc7786605-0                                                  rostral
# SS.sc7785737-0                                                   caudal
# SS.sc7785398-0                                                 yolk sac
# SS.sc7788091-0                                                   caudal
# ...                                                                 ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                            NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                            NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                            NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                            NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                            NaN
#
#                                          Characteristics.inferred.cell.type...authors.labels.  \
# SS.sc7786612-0                                                              endodermal cell
# SS.sc7786605-0                                                            advanced mesoderm
# SS.sc7785737-0                                                             primitive streak
# SS.sc7785398-0                                                            yolk sac mesoderm
# SS.sc7788091-0                                                               axial mesoderm
# ...                                                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                                                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                                                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                                                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                                                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                                                NaN
#
#                                          Characteristics.inferred.cell.type...ontology.labels.  \
# SS.sc7786612-0                                                              endodermal cell
# SS.sc7786605-0                                                                mesoderm cell
# SS.sc7785737-0                                                        primitive streak cell
# SS.sc7785398-0                                                       mesenchyme of yolk sac
# SS.sc7788091-0                                                        chordamesodermal cell
# ...                                                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                                                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                                                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                                                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                                                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                                                NaN
#
#                                                  cluster_id  \
# SS.sc7786612-0                                     Endoderm
# SS.sc7786605-0                            Advanced Mesoderm
# SS.sc7785737-0                             Primitive Streak
# SS.sc7785398-0                                 ExE Mesoderm
# SS.sc7788091-0                               Axial Mesoderm
# ...                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                NaN
#
#                                                 sub_cluster origin    run  \
# SS.sc7786612-0                                        DE(P)  tyser  tyser
# SS.sc7786605-0                            Advanced Mesoderm  tyser  tyser
# SS.sc7785737-0                             Primitive Streak  tyser  tyser
# SS.sc7785398-0                                  YS Mesoderm  tyser  tyser
# SS.sc7788091-0                               Axial Mesoderm  tyser  tyser
# ...                                                     ...    ...    ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                NaN    NaN   120h
#
#                                          sample_name timepoint  percent.mt  \
# SS.sc7786612-0                                 tyser     tyser    1.304482
# SS.sc7786605-0                                 tyser     tyser    1.295160
# SS.sc7785737-0                                 tyser     tyser    1.294179
# SS.sc7785398-0                                 tyser     tyser    1.423720
# SS.sc7788091-0                                 tyser     tyser    1.327328
# ...                                              ...       ...         ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1   iPSC_72_1       NaN    4.767002
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1   iPSC_72_1       NaN    4.127899
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1   iPSC_72_1       NaN    2.035554
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1   iPSC_72_1       NaN    3.428081
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1   iPSC_72_1       NaN    2.722464
#
#                                               batch  percent.dissoc  \
# SS.sc7786612-0                            reference             NaN
# SS.sc7786605-0                            reference             NaN
# SS.sc7785737-0                            reference             NaN
# SS.sc7785398-0                            reference             NaN
# SS.sc7788091-0                            reference             NaN
# ...                                             ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1  reference        0.017398
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1  reference        0.014142
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1  reference        0.013721
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1  reference        0.015297
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1  reference        0.013653
#
#                                          RNA_snn_res.0.3 seurat_clusters  \
# SS.sc7786612-0                                       NaN             NaN
# SS.sc7786605-0                                       NaN             NaN
# SS.sc7785737-0                                       NaN             NaN
# SS.sc7785398-0                                       NaN             NaN
# SS.sc7788091-0                                       NaN             NaN
# ...                                                  ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1               3               2
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1               5               4
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1               3               2
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1               3               2
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1               3               2
#
#                                           RNA_snn_res.0.22 batch_join
# SS.sc7786612-0                                         NaN          0
# SS.sc7786605-0                                         NaN          0
# SS.sc7785737-0                                         NaN          0
# SS.sc7785398-0                                         NaN          0
# SS.sc7788091-0                                         NaN          0
# ...                                                    ...        ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1               2.0          1
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1               4.0          1
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1               2.0          1
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1               2.0          1
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1               2.0          1
#
# [5763 rows x 20 columns]

# %%
dataset_samen.obsm['X_cvae'] = q_intr_cvae.get_latent(dataset_samen.X, dataset_samen.obs['batch'], mean=MEAN, only_active=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 dataset_samen.obsm['X_cvae'] = q_intr_cvae.get_latent(dataset_samen.X, dataset_samen.obs['batch'], mean=MEAN, only_active=True)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scarches\models\expimap\expimap_model.py:282, in EXPIMAP.get_latent(self, x, c, only_active, mean, mean_var)
#     251 def get_latent(
#     252     self,
#     253     x: Optional[np.ndarray] = None,
#    (...)
#     257     mean_var: bool = False
#     258 ):
#     259     """Map `x` in to the latent space. This function will feed data in encoder
#     260        and return z for each sample in data.
#     261
#    (...)
#     280             Returns array containing latent space encoding of 'x'.
#     281     """
# --> 282     result = super().get_latent(x, c, mean, mean_var)
#     284     if not only_active:
#     285         return result
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scarches\models\base\_base.py:333, in CVAELatentsMixin.get_latent(self, x, c, mean, mean_var)
#     331     x_batch = x_batch.toarray()
#     332 x_batch = torch.tensor(x_batch, device=device)
# --> 333 latent = self.model.get_latent(x_batch, c[batch], mean, mean_var)
#     334 latent = (latent,) if not isinstance(latent, tuple) else latent
#     335 latents += [tuple(l.cpu().detach() for l in latent)]
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scarches\models\base\_base.py:426, in CVAELatentsModelMixin.get_latent(self, x, c, mean, mean_var)
#     424 if self.recon_loss == 'mse':
#     425     x_ = x
# --> 426 z_mean, z_log_var = self.encoder(x_, c)
#     427 latent = self.sampling(z_mean, z_log_var)
#     428 if mean:
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scarches\models\expimap\modules.py:208, in ExtEncoder.forward(self, x, batch)
#     206     x = torch.cat((x, batch), dim=-1)
#     207 if self.FC is not None:
# --> 208     x = self.FC(x)
#     209 means = self.mean_encoder(x)
#     210 log_vars = self.log_var_encoder(x)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scarches\models\expimap\modules.py:78, in MaskedCondLayers.forward(self, x)
#      75 else:
#      76     expr, ext_m = torch.split(expr, [expr.shape[1] - self.n_ext_m, self.n_ext_m], dim=1)
# ---> 78 out = self.expr_L(expr)
#      79 if ext is not None:
#      80     out = out + self.ext_L(ext)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (512x1841 and 1977x256)

# %%
# Out:
# (4694, 263)
