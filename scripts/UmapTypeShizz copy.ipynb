# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
import scanpy as sc
import torch
import scarches as sca
import numpy as np
import gdown

# %%
sc.set_figure_params(frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %%
adata = sc.read('tyser.h5ad')
#hips = sc.read("hiPSC.h5ad")

# %%
adata.T
# Out:
# AnnData object with n_obs × n_vars = 57490 × 1069
#     obs: 'features'
#     var: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt'

# %%
print(adata.X.shape)
print(adata.X[:5, :5])  # View a small slice
# Out:
# (1069, 57490)
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3 stored elements and shape (5, 5)>
#   Coords	Values
#   (0, 0)	2.0
#   (2, 0)	2.0
#   (4, 1)	1.0

# %%
#adata.X = adata.layers["counts"].copy()
# Use adata.X directly, as it contains raw counts.
adata.X = adata.X.copy()

# %%
sca.utils.add_annotations(adata, 'reactome.gmt', min_genes=12, clean=True)

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1)>0)

# %%
sc.pp.normalize_total(adata)

# %%
sc.pp.log1p(adata)

# %%
print(adata.obs.keys())
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name',
#        'Characteristics.sampling.site.',
#        'Characteristics.inferred.cell.type...authors.labels.',
#        'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id',
#        'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint',
#        'percent.mt'],
#       dtype='object')

# %%
#adata.obs['batch'] = 'reference'
dataset_samen.
# Out:
#               orig.ident     nCount_RNA  nFeature_RNA   Source.Name  \
# SS.sc7786612           0  259888.990001          6942  SS.sc7786612
# SS.sc7786605           0  437911.014986          6140  SS.sc7786605
# SS.sc7785737           0  322351.983054          3800  SS.sc7785737
# SS.sc7785398           0  394318.996000          2964  SS.sc7785398
# SS.sc7788091           0  298217.993000          5030  SS.sc7788091
# ...                  ...            ...           ...           ...
# SS.sc7785965           0  226569.027995          6361  SS.sc7785965
# SS.sc7788259           0  353921.980998          4647  SS.sc7788259
# SS.sc7786123           0  366998.009999          2822  SS.sc7786123
# SS.sc7786212           0  459601.642974          6110  SS.sc7786212
# SS.sc7785932           0  349231.986990          5612  SS.sc7785932
#
#              Characteristics.sampling.site.  \
# SS.sc7786612                        rostral
# SS.sc7786605                        rostral
# SS.sc7785737                         caudal
# SS.sc7785398                       yolk sac
# SS.sc7788091                         caudal
# ...                                     ...
# SS.sc7785965                         caudal
# SS.sc7788259                         caudal
# SS.sc7786123                         caudal
# SS.sc7786212                         caudal
# SS.sc7785932                         caudal
#
#              Characteristics.inferred.cell.type...authors.labels.  \
# SS.sc7786612                                    endodermal cell
# SS.sc7786605                                  advanced mesoderm
# SS.sc7785737                                   primitive streak
# SS.sc7785398                                  yolk sac mesoderm
# SS.sc7788091                                     axial mesoderm
# ...                                                         ...
# SS.sc7785965                                      epiblast cell
# SS.sc7788259                                   primitive streak
# SS.sc7786123                                   primitive streak
# SS.sc7786212                                      epiblast cell
# SS.sc7785932                                   nascent mesoderm
#
#              Characteristics.inferred.cell.type...ontology.labels.  \
# SS.sc7786612                                    endodermal cell
# SS.sc7786605                                      mesoderm cell
# SS.sc7785737                              primitive streak cell
# SS.sc7785398                             mesenchyme of yolk sac
# SS.sc7788091                              chordamesodermal cell
# ...                                                         ...
# SS.sc7785965                                      epiblast cell
# SS.sc7788259                              primitive streak cell
# SS.sc7786123                              primitive streak cell
# SS.sc7786212                                      epiblast cell
# SS.sc7785932                                    mesodermal cell
#
#                      cluster_id        sub_cluster origin    run sample_name  \
# SS.sc7786612           Endoderm              DE(P)  tyser  tyser       tyser
# SS.sc7786605  Advanced Mesoderm  Advanced Mesoderm  tyser  tyser       tyser
# SS.sc7785737   Primitive Streak   Primitive Streak  tyser  tyser       tyser
# SS.sc7785398       ExE Mesoderm        YS Mesoderm  tyser  tyser       tyser
# SS.sc7788091     Axial Mesoderm     Axial Mesoderm  tyser  tyser       tyser
# ...                         ...                ...    ...    ...         ...
# SS.sc7785965           Epiblast           Epiblast  tyser  tyser       tyser
# SS.sc7788259   Primitive Streak   Primitive Streak  tyser  tyser       tyser
# SS.sc7786123   Primitive Streak   Primitive Streak  tyser  tyser       tyser
# SS.sc7786212           Epiblast           Epiblast  tyser  tyser       tyser
# SS.sc7785932   Nascent Mesoderm   Nascent Mesoderm  tyser  tyser       tyser
#
#              timepoint  percent.mt      batch
# SS.sc7786612     tyser    1.304482  reference
# SS.sc7786605     tyser    1.295160  reference
# SS.sc7785737     tyser    1.294179  reference
# SS.sc7785398     tyser    1.423720  reference
# SS.sc7788091     tyser    1.327328  reference
# ...                ...         ...        ...
# SS.sc7785965     tyser    1.675409  reference
# SS.sc7788259     tyser    1.615045  reference
# SS.sc7786123     tyser    1.602395  reference
# SS.sc7786212     tyser    1.150624  reference
# SS.sc7785932     tyser    1.406839  reference
#
# [1069 rows x 15 columns]

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=2000,
    batch_key="batch",
    subset=True)

# %%
select_terms = adata.varm['I'].sum(0) > 12
adata.uns['terms'] = np.array(adata.uns['terms'])[select_terms].tolist()
adata.varm['I'] = adata.varm['I'][:, select_terms]

# %%
adata._inplace_subset_var(adata.varm['I'].sum(1) > 0)

# %%
adata.X = adata.X.copy()

# %%
intr_cvae = sca.models.EXPIMAP(
    adata=adata,
    condition_key='batch',
    hidden_layer_sizes=[256, 256, 256],
    recon_loss='nb'
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1841 256 1
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 224
# Decoder Architecture:
# 	Masked linear layer in, ext_m, ext, cond, out:  224 0 0 1 1841
# 	with hard mask.
# Last Decoder layer: softmax

# %%
ALPHA = 0.7

# %%
adata.X = adata.X.astype(np.float32)

# %%
early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss", # val_unweighted_loss
    "threshold": 0,
    "patience": 50,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}
intr_cvae.train(
    n_epochs=400,
    alpha_epoch_anneal=100,
    alpha=ALPHA,
    alpha_kl=0.5,
    weight_decay=0.,
    early_stopping_kwargs=early_stopping_kwargs,
    use_early_stopping=True,
    monitor_only_val=False,
    seed=2020,
)
# Out:
# Preparing (1069, 1841)
# Instantiating dataset
# Init the group lasso proximal operator for the main terms.
#  |████████████████████| 100.0%  - epoch_loss: 1308.1874084473 - epoch_recon_loss: 1276.7711639404 - epoch_kl_loss: 62.8324499130 - val_loss: 1316.1992187500 - val_recon_loss: 1284.4739990234 - val_kl_loss: 63.450359344531
# Saving best state of network...
# Best State was in Epoch 398

# %%
MEAN = False

# %%
adata.obsm['X_cvae'] = intr_cvae.get_latent(mean=MEAN, only_active=True)

# %%
sc.pp.neighbors(adata, use_rep='X_cvae')

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['Characteristics.inferred.cell.type...authors.labels.'], frameon=False)

# %%
# Lees de query-dataset
hips = sc.read('hiPSC.h5ad')

# Controleer de overlap van genen
missing_genes = [gene for gene in adata.var_names if gene not in hips.var_names]
print(f"Aantal genen in hips die niet in tyser staan: {len(missing_genes)}")
print("Ontbrekende genen:", missing_genes)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[283], line 2
#       1 # Lees de query-dataset
# ----> 2 hips = sc.read('hiPSC.h5ad')
#       4 # Controleer de overlap van genen
#       5 missing_genes = [gene for gene in adata.var_names if gene not in hips.var_names]
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\legacy_api_wrap\__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      79 @wraps(fn)
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      81     if len(args_all) <= n_positional:
# ---> 82         return fn(*args_all, **kw)
#      84     args_pos: P.args
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scanpy\readwrite.py:142, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     140 filename = Path(filename)  # allow passing strings
#     141 if is_valid_filename(filename):
# --> 142     return _read(
#     143         filename,
#     144         backed=backed,
#     145         sheet=sheet,
#     146         ext=ext,
#     147         delimiter=delimiter,
#     148         first_column_names=first_column_names,
#     149         backup_url=backup_url,
#     150         cache=cache,
#     151         cache_compression=cache_compression,
#     152         **kwargs,
#     153     )
#     154 # generate filename and read to dict
#     155 filekey = str(filename)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\scanpy\readwrite.py:777, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     775 if ext in {"h5", "h5ad"}:
#     776     if sheet is None:
# --> 777         return read_h5ad(filename, backed=backed)
#     778     else:
#     779         logg.debug(f"reading sheet {sheet} from file {filename}")
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\h5ad.py:260, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     257         return read_dataframe(elem)
#     258     return func(elem)
# --> 260 adata = read_dispatched(f, callback=callback)
#     262 # Backwards compat (should figure out which version)
#     263 if "raw.X" in f:
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\utils.py:212, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     210     raise ValueError("No element found in args.")
#     211 try:
# --> 212     return func(*args, **kwargs)
#     213 except Exception as e:
#     214     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\specs\registry.py:282, in Reader.read_elem(self, elem, modifiers)
#     280 if self.callback is None:
#     281     return read_func(elem)
# --> 282 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\h5ad.py:244, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     238 def callback(func, elem_name: str, elem, iospec):
#     239     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     240         return AnnData(
#     241             **{
#     242                 # This is covering up backwards compat in the anndata initializer
#     243                 # In most cases we should be able to call `func(elen[k])` instead
# --> 244                 k: read_dispatched(elem[k], callback)
#     245                 for k in elem.keys()
#     246                 if not k.startswith("raw.")
#     247             }
#     248         )
#     249     elif elem_name.startswith("/raw."):
#     250         return None
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\utils.py:212, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     210     raise ValueError("No element found in args.")
#     211 try:
# --> 212     return func(*args, **kwargs)
#     213 except Exception as e:
#     214     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\specs\registry.py:282, in Reader.read_elem(self, elem, modifiers)
#     280 if self.callback is None:
#     281     return read_func(elem)
# --> 282 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\h5ad.py:254, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     252     return rdasp(elem)
#     253 elif elem_name == "/raw":
# --> 254     return _read_raw(f, as_sparse, rdasp)
#     255 elif elem_name in {"/obs", "/var"}:
#     256     # Backwards compat
#     257     return read_dataframe(elem)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\h5ad.py:287, in _read_raw(f, as_sparse, rdasp, attrs)
#     285 if "X" in attrs and "raw/X" in f:
#     286     read_x = rdasp if "raw/X" in as_sparse else read_elem
# --> 287     raw["X"] = read_x(f["raw/X"])
#     288 for v in ("var", "varm"):
#     289     if v in attrs and f"raw/{v}" in f:
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\specs\registry.py:378, in read_elem(elem)
#     366 def read_elem(elem: StorageType) -> RWAble:
#     367     """
#     368     Read an element from a store.
#     369
#    (...)
#     376         The stored element.
#     377     """
# --> 378     return Reader(_REGISTRY).read_elem(elem)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\utils.py:212, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     210     raise ValueError("No element found in args.")
#     211 try:
# --> 212     return func(*args, **kwargs)
#     213 except Exception as e:
#     214     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\specs\registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     277 read_func: Read = self.registry.get_read(
#     278     type(elem), iospec, modifiers, reader=self
#     279 )
#     280 if self.callback is None:
# --> 281     return read_func(elem)
#     282 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_io\specs\methods.py:761, in read_sparse(elem, _reader)
#     754 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     755 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     756 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#    (...)
#     759     elem: GroupStorageType, *, _reader: Reader
#     760 ) -> sparse.spmatrix | SpArray:
# --> 761     return sparse_dataset(elem).to_memory()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\anndata\_core\sparse_dataset.py:581, in BaseCompressedSparseDataset.to_memory(self)
#     577 format_class = get_memory_class(
#     578     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     579 )
#     580 mtx = format_class(self.shape, dtype=self.dtype)
# --> 581 mtx.data = self.group["data"][...]
#     582 mtx.indices = self.group["indices"][...]
#     583 mtx.indptr = self._indptr
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File c:\Users\Mick\PycharmProjects\BPEXA\in_house_data\venv\in-house\.venv\Lib\site-packages\h5py\_hl\dataset.py:781, in Dataset.__getitem__(self, args, new_dtype)
#     779 if self._fast_read_ok and (new_dtype is None):
#     780     try:
# --> 781         return self._fast_reader.read(args)
#     782     except TypeError:
#     783         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
# Filter genen die aanwezig zijn in beide datasets
common_genes = [gene for gene in adata.var_names if gene in hips.var_names]

# Pas de filtering toe op beide datasets
hips = hips[:, common_genes].copy()
adata = adata[:, common_genes].copy()

# %%
hips = sc.read('hiPSC.h5ad')

commom = adata.var_names.intersection(hips.var_names)
hips = hips[:, commom].copy()

hips
# Out:
# AnnData object with n_obs × n_vars = 4694 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'run', 'sample_name', 'percent.mt', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22'
#     var: 'features'
#     uns: 'neighbors'
#     obsm: 'X_mnn', 'X_umap'
#     obsp: 'distances'

# %%
intr_cvae.adata
# Out:
# AnnData object with n_obs × n_vars = 1069 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt', 'batch'
#     var: 'features', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'terms', 'log1p', 'hvg', 'neighbors', 'umap', 'Characteristics.inferred.cell.type...authors.labels._colors'
#     obsm: 'X_cvae', 'X_umap'
#     varm: 'I'
#     obsp: 'distances', 'connectivities'

# %%
#hips = sc.read('hiPSC.h5ad')[:, adata.var_names].copy()

# %%
# Controleer of var_names overeenkomen
#print("Aantal genen in beide datasets na filtering:", len(common_genes))
#print("Zijn genen nu identiek?", np.array_equal(hips.var_names, hips.var_names))

# %%
hips.obs['batch'] = 'query'

# %%
dataset_samen.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 2205588 stored elements and shape (5763, 1841)>

# %%
hips.X = hips.X.astype(np.float32)

# %%
q_intr_cvae = sca.models.EXPIMAP.load_query_data(hips, intr_cvae)
# Out:
# AnnData object with n_obs × n_vars = 4694 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'run', 'sample_name', 'percent.mt', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22', 'batch'
#     var: 'features'
#     uns: 'neighbors'
#     obsm: 'X_mnn', 'X_umap'
#     obsp: 'distances'
#
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 1841 256 2
# 	Hidden Layer 1 in/out: 256 256
# 	Hidden Layer 2 in/out: 256 256
# 	Mean/Var Layer in/out: 256 224
# Decoder Architecture:
# 	Masked linear layer in, ext_m, ext, cond, out:  224 0 0 2 1841
# 	with hard mask.
# Last Decoder layer: softmax

# %%
q_intr_cvae.train(n_epochs=400, alpha_epoch_anneal=100, weight_decay=0., alpha_kl=0.1, seed=2020, use_early_stopping=True)
# Out:
# Preparing (4694, 1841)
# Instantiating dataset
#  |███████████---------| 59.8%  - val_loss: 1130.1795043945 - val_recon_loss: 1125.0456848145 - val_kl_loss: 51.3380908966
# ADJUSTED LR
#  |████████████--------| 61.5%  - val_loss: 1128.3386535645 - val_recon_loss: 1123.2088623047 - val_kl_loss: 51.2980089188
# Stopping early: no improvement of more than 0 nats in 20 epochs
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Saving best state of network...
# Best State was in Epoch 245

# %%
dataset_samen = sc.AnnData.concatenate(adata, hips, batch_key='batch_join', uns_merge='same')

# %%
dataset_samen
# Out:
# AnnData object with n_obs × n_vars = 5763 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt', 'batch', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22', 'batch_join'
#     var: 'features', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'highly_variable_nbatches-0', 'highly_variable_intersection-0'
#     obsm: 'X_umap'

# %%
dataset_samen.X = dataset_samen.X.astype(np.float32)
#adata.X = adata.X.astype(np.float32)

# %%
dataset_samen.obs.batch
# Out:
# SS.sc7786612-0                              reference
# SS.sc7786605-0                              reference
# SS.sc7785737-0                              reference
# SS.sc7785398-0                              reference
# SS.sc7788091-0                              reference
#                                               ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1        query
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1        query
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1        query
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1        query
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1        query
# Name: batch, Length: 5763, dtype: object

# %%
dataset_samen.X.shape
# Out:
# (5763, 1841)

# %%
#print("X shape:", dataset_samen.X.shape)  # Should output something like (512, 1841)
#print("batch shape:", dataset_samen.obs['batch'].shape)  # Should output the shape of the batch column
#dataset_samen.obs['batch']
# 
dataset_samen.obs['batch'].value_counts()
# Out:
# query        4694
# reference    1069
# Name: batch, dtype: int64

# %%
q_intr_cvae

# %%
dataset_samen.obsm['X_cvae'] = q_intr_cvae.get_latent(dataset_samen.X, dataset_samen.obs['batch'], mean=MEAN, only_active=True)

# %%
sc.pp.neighbors(dataset_samen, use_rep='X_cvae')

# %%
sc.tl.umap(dataset_samen)

# %%
dataset_samen.obs
# Out:
#                                              orig.ident     nCount_RNA  \
# SS.sc7786612-0                                        0  259888.990001
# SS.sc7786605-0                                        0  437911.014986
# SS.sc7785737-0                                        0  322351.983054
# SS.sc7785398-0                                        0  394318.996000
# SS.sc7788091-0                                        0  298217.993000
# ...                                                 ...            ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1  SeuratProject   14013.000000
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1  SeuratProject   21173.000000
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1  SeuratProject   22107.000000
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1  SeuratProject   12806.000000
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1  SeuratProject   32140.000000
#
#                                           nFeature_RNA   Source.Name  \
# SS.sc7786612-0                                    6942  SS.sc7786612
# SS.sc7786605-0                                    6140  SS.sc7786605
# SS.sc7785737-0                                    3800  SS.sc7785737
# SS.sc7785398-0                                    2964  SS.sc7785398
# SS.sc7788091-0                                    5030  SS.sc7788091
# ...                                                ...           ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1          4629           NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1          5140           NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1          5437           NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1          4127           NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1          5614           NaN
#
#                                          Characteristics.sampling.site.  \
# SS.sc7786612-0                                                  rostral
# SS.sc7786605-0                                                  rostral
# SS.sc7785737-0                                                   caudal
# SS.sc7785398-0                                                 yolk sac
# SS.sc7788091-0                                                   caudal
# ...                                                                 ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                            NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                            NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                            NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                            NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                            NaN
#
#                                          Characteristics.inferred.cell.type...authors.labels.  \
# SS.sc7786612-0                                                              endodermal cell
# SS.sc7786605-0                                                            advanced mesoderm
# SS.sc7785737-0                                                             primitive streak
# SS.sc7785398-0                                                            yolk sac mesoderm
# SS.sc7788091-0                                                               axial mesoderm
# ...                                                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                                                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                                                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                                                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                                                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                                                NaN
#
#                                          Characteristics.inferred.cell.type...ontology.labels.  \
# SS.sc7786612-0                                                              endodermal cell
# SS.sc7786605-0                                                                mesoderm cell
# SS.sc7785737-0                                                        primitive streak cell
# SS.sc7785398-0                                                       mesenchyme of yolk sac
# SS.sc7788091-0                                                        chordamesodermal cell
# ...                                                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                                                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                                                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                                                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                                                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                                                NaN
#
#                                                  cluster_id  \
# SS.sc7786612-0                                     Endoderm
# SS.sc7786605-0                            Advanced Mesoderm
# SS.sc7785737-0                             Primitive Streak
# SS.sc7785398-0                                 ExE Mesoderm
# SS.sc7788091-0                               Axial Mesoderm
# ...                                                     ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                NaN
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                NaN
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                NaN
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                NaN
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                NaN
#
#                                                 sub_cluster origin    run  \
# SS.sc7786612-0                                        DE(P)  tyser  tyser
# SS.sc7786605-0                            Advanced Mesoderm  tyser  tyser
# SS.sc7785737-0                             Primitive Streak  tyser  tyser
# SS.sc7785398-0                                  YS Mesoderm  tyser  tyser
# SS.sc7788091-0                               Axial Mesoderm  tyser  tyser
# ...                                                     ...    ...    ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1                NaN    NaN   120h
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1                NaN    NaN   120h
#
#                                          sample_name timepoint  percent.mt  \
# SS.sc7786612-0                                 tyser     tyser    1.304482
# SS.sc7786605-0                                 tyser     tyser    1.295160
# SS.sc7785737-0                                 tyser     tyser    1.294179
# SS.sc7785398-0                                 tyser     tyser    1.423720
# SS.sc7788091-0                                 tyser     tyser    1.327328
# ...                                              ...       ...         ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1   iPSC_72_1       NaN    4.767002
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1   iPSC_72_1       NaN    4.127899
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1   iPSC_72_1       NaN    2.035554
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1   iPSC_72_1       NaN    3.428081
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1   iPSC_72_1       NaN    2.722464
#
#                                               batch  percent.dissoc  \
# SS.sc7786612-0                            reference             NaN
# SS.sc7786605-0                            reference             NaN
# SS.sc7785737-0                            reference             NaN
# SS.sc7785398-0                            reference             NaN
# SS.sc7788091-0                            reference             NaN
# ...                                             ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1      query        0.017398
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1      query        0.014142
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1      query        0.013721
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1      query        0.015297
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1      query        0.013653
#
#                                          RNA_snn_res.0.3 seurat_clusters  \
# SS.sc7786612-0                                       NaN             NaN
# SS.sc7786605-0                                       NaN             NaN
# SS.sc7785737-0                                       NaN             NaN
# SS.sc7785398-0                                       NaN             NaN
# SS.sc7788091-0                                       NaN             NaN
# ...                                                  ...             ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1               3               2
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1               5               4
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1               3               2
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1               3               2
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1               3               2
#
#                                           RNA_snn_res.0.22 batch_join
# SS.sc7786612-0                                         NaN          0
# SS.sc7786605-0                                         NaN          0
# SS.sc7785737-0                                         NaN          0
# SS.sc7785398-0                                         NaN          0
# SS.sc7788091-0                                         NaN          0
# ...                                                    ...        ...
# batch_1_sample_120H_TTTACTGCATCCGCGA-1-1               2.0          1
# batch_1_sample_120H_TTTCACATCAGCCCAG-1-1               4.0          1
# batch_1_sample_120H_TTTCAGTAGTACAGAT-1-1               2.0          1
# batch_1_sample_120H_TTTGATCAGCTCCATA-1-1               2.0          1
# batch_1_sample_120H_TTTGTTGAGTTGGCGA-1-1               2.0          1
#
# [5763 rows x 20 columns]

# %%
sc.pl.umap(dataset_samen, color=['batch'], frameon=False, wspace=0.6)

# %%
sc.pl.umap(dataset_samen, color=['Characteristics.inferred.cell.type...authors.labels.'], frameon=False, wspace=0.6)

# %%
sc.pl.umap(dataset_samen, color=['seurat_clusters'], frameon=False, wspace=0.6)

# %%
dataset_samen.strings_to_categoricals()
dataset_samen
# Out:
# AnnData object with n_obs × n_vars = 5763 × 1841
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Source.Name', 'Characteristics.sampling.site.', 'Characteristics.inferred.cell.type...authors.labels.', 'Characteristics.inferred.cell.type...ontology.labels.', 'cluster_id', 'sub_cluster', 'origin', 'run', 'sample_name', 'timepoint', 'percent.mt', 'batch', 'percent.dissoc', 'RNA_snn_res.0.3', 'seurat_clusters', 'RNA_snn_res.0.22', 'batch_join'
#     var: 'features', 'highly_variable-0', 'means-0', 'dispersions-0', 'dispersions_norm-0', 'highly_variable_nbatches-0', 'highly_variable_intersection-0'
#     uns: 'neighbors', 'umap', 'batch_colors', 'Characteristics.inferred.cell.type...authors.labels._colors', 'seurat_clusters_colors', 'terms'
#     obsm: 'X_umap', 'X_cvae'
#     obsp: 'distances', 'connectivities'

# %%
#dataset_samen.obs["orig.ident"] = dataset_samen.obs["orig.ident"].tolist()
#dataset_samen.obs["orig.ident"]
# Zet alle waarden in de kolom 'orig.ident' om naar strings
dataset_samen.obs['orig.ident'] = dataset_samen.obs['orig.ident'].astype(str)


dataset_samen.write('hipstyser_integrated.h5ad')
